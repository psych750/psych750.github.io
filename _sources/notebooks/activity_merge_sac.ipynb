# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.7     v dplyr   1.0.8
# v tidyr   1.2.0     v stringr 1.4.0
# v readr   2.1.2     v forcats 0.5.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
iris %>% group_by(Species) %>% mutate(normed.sepal.length = scale(Sepal.Length)) %>% head
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species normed.sepal.length
# 1 5.1          3.5         1.4          0.2         setosa   0.26667447
# 2 4.9          3.0         1.4          0.2         setosa  -0.30071802
# 3 4.7          3.2         1.3          0.2         setosa  -0.86811050
# 4 4.6          3.1         1.5          0.2         setosa  -1.15180675
# 5 5.0          3.6         1.4          0.2         setosa  -0.01702177
# 6 5.4          3.9         1.7          0.4         setosa   1.11776320
